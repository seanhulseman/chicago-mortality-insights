# %% [markdown]
# ## topic modeling exploration

# %% [markdown]
# Credits:<br>
# Ria Kulshrestha, https://towardsdatascience.com/latent-dirichlet-allocation-lda-9d1cd064ffa2 <br>
# Susan Li, https://towardsdatascience.com/topic-modeling-and-latent-dirichlet-allocation-in-python-9bf156893c24

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# import sys
import gensim
from gensim.utils import simple_preprocess
from gensim.parsing.preprocessing import STOPWORDS
from gensim import corpora, models

from nltk.stem import WordNetLemmatizer, PorterStemmer
from nltk.stem.porter import *
import nltk
# nltk.download('wordnet') # only need to do once?

# %%
df = pd.read_csv('../susan/data/cleaned_data_31OCT.csv')
# df.sample(5)

# %%
# https://stackoverflow.com/questions/1987694/how-do-i-print-the-full-numpy-array-without-truncation
pd.set_option('display.max_rows', None)

df['primary_cause_line_b'].sample(500)
# Out:
# 15391                                              no_text
# 11450                                              no_text
# 35363                    MOTOR VEHICLE STRIKING PEDESTRIAN
# 12044                                              no_text
# 25268                                              no_text
# 1948                                               HANGING
# 31109                                              no_text
# 36215                                                 FALL
# 11946                                                 FALL
# 16685                  ...PROBABLE FLUALPRAZOLAM) TOXICITY
# 10532                                              no_text
# 3998                                               no_text
# 33844                       CHRONIC ETHANOL AND DRUG ABUSE
# 1068                                         PROBABLE FALL
# 15131                                              no_text
# 2693                                               no_text
# 11431                             UNSAFE SLEEP ENVIRONMENT
# 1055                                                  FALL
# 1147                                               no_text
# 33029                                                 FALL
# 28084                                              no_text
# 14680                                              no_text
# 29928                                     FALL DOWN STAIRS
# 21956    COMBINED DRUG (HEROIN, FENTANYL & ACETYL FENTA...
# 1781                                               no_text
# 3131                         REMOTE MOTOR VEHICLE ACCIDENT
# 311                                MOTOR VEHICLE COLLISION
# 32712                                              no_text
# 14444                                              no_text
# 563                                                no_text
# 12595                                              no_text
# 720                                                no_text
# 2610                                               no_text
# 22876                                              no_text
# 5797     ...PROMETHAZINE, AND 3,4-METHYLENEDIOXYMETHAMP...
# 1755                                                  FALL
# 8588                                               no_text
# 27969                    MOTOR VEHICLE STRIKING PEDESTRIAN
# 30102    DIHYDROCODEINE/HYDROCODOL, OXYCODONE, OXYMORPH...
# 21304                                              no_text
# 32151                                     BRONCHOPNEUMONIA
# 14959                                              no_text
# 4680                                               no_text
# 3019                                                  FALL
# 16404                                              no_text
# 6095                                               no_text
# 16490                                              no_text
# 31063                                              no_text
# 13175                                     RESIDENTIAL FIRE
# 6796                                               no_text
# 7599                                               no_text
# 20547                    MOTOR VEHICLE STRIKING PEDESTRIAN
# 28909                                              no_text
# 2452                                               no_text
# 15896                                              no_text
# 9304                                               no_text
# 3477                                               no_text
# 13765                                              no_text
# 6989                                               no_text
# 14235                              MOTOR VEHICLE COLLISION
# 28853                            TRAIN STRIKING PEDESTRIAN
# 20721                                                 FALL
# 2498                                               no_text
# 2231                                               no_text
# 25109                     SPORTS UTILITY VEHICLE COLLISION
# 34067                              MOTOR VEHICLE COLLISION
# 22027                                              no_text
# 27192                                              no_text
# 22118                    MOTOR VEHICLE STRIKING PEDESTRIAN
# 9945                                               no_text
# 12343                                              no_text
# 18687                                                 FALL
# 17247                       TRAIN AND SEMI-TRUCK COLLISION
# 22778                                              no_text
# 20879                                                 FALL
# 27033                                              no_text
# 2946                                               no_text
# 9782                                      JUMP FROM HEIGHT
# 22435                                              no_text
# 35169                                  HEROIN INTOXICATION
# 12098                                              no_text
# 26092                                              no_text
# 27293                              MOTOR VEHICLE COLLISION
# 20316                                              no_text
# 12122                                              no_text
# 2819                                           CHILD ABUSE
# 14227                                              no_text
# 31155                                              no_text
# 13148                    MOTOR VEHICLE STRIKING PEDESTRIAN
# 15533                                     FALL DOWN STAIRS
# 5588                                               no_text
# 21872                                              no_text
# 5001                                               no_text
# 16963                                              no_text
# 1297                                               no_text
# 26198                                              no_text
# 23375                                              no_text
# 23690                                              no_text
# 2206                                               no_text
# 29795                                              no_text
# 30327                                              no_text
# 24489                                              no_text
# 19302                                              no_text
# 18021                                              no_text
# 19608                                              no_text
# 24737                                                 FALL
# 21962                                              no_text
# 11197                                 FALL FROM WHEELCHAIR
# 15388                       ...FENTANYL (4-ANPP)) TOXICITY
# 12866    COMBINED COCAINE, ETHANOL, AND METHAMPHETAMINE...
# 13862                  MOTOR VEHICLE STRIKING FIXED OBJECT
# 33565                                CHOKING ON FOOD BOLUS
# 10149                                              no_text
# 15079                                              no_text
# 35993                                              no_text
# 33260                                              no_text
# 32209                                                 FALL
# 13298              NOVEL CORONA (COVID-19) VIRAL INFECTION
# 32778                                              no_text
# 13812              NOVEL CORONA (COVID-19) VIRAL INFECTION
# 4744                                               no_text
# 28343                                              no_text
# 455                                                no_text
# 30797                                              no_text
# 5336                                               no_text
# 24599                                              no_text
# 16676                                              no_text
# 35100                              MOTOR VEHICLE COLLISION
# 7017                                               no_text
# 36311                                              no_text
# 2235                                               no_text
# 25694                   PEDESTRIAN STRUCK BY MOTOR VEHICLE
# 6771                                               no_text
# 24106                                              no_text
# 7899                                               no_text
# 19677                                              no_text
# 27013                                     UNWITNESSED FALL
# 16455                    ... FENTANYL, AND HEROIN TOXICITY
# 35596                                              no_text
# 14616                                              no_text
# 27953                                              no_text
# 35828                                              no_text
# 23126                                  INDUSTRIAL ACCIDENT
# 14074                                              no_text
# 18340                                              no_text
# 27364                                              no_text
# 4112                                               no_text
# 35500                           BLUNT FORCE IMPACT TO HEAD
# 10451                          UNSAFE SLEEPING ENVIRONMENT
# 21131                    MOTOR VEHICLE STRIKING PEDESTRIAN
# 3749                                               no_text
# 20853                                              no_text
# 27080                   MOTORCYCLE IN COLLISION WITH TRUCK
# 11251                                              no_text
# 31565                                              no_text
# 4296                                                  FALL
# 36428                                              no_text
# 20901                                              no_text
# 23028                                              no_text
# 24758                                              no_text
# 13839                    MOTOR VEHICLE STRIKING PEDESTRIAN
# 8626                               MOTOR VEHICLE COLLISION
# 9029                                               no_text
# 32833                                              no_text
# 24886                                              no_text
# 11044                                                 FALL
# 15000                                              no_text
# 35509                               MOTOR VEHICLE ACCIDENT
# 35345                              MOTOR VEHICLE COLLISION
# 22910                                              no_text
# 28231                                              no_text
# 11735                                              no_text
# 15938                  MOTOR VEHICLE STRIKING FIXED OBJECT
# 14160                                              no_text
# 36131                                              no_text
# 12687                                                 FALL
# 30355                                              no_text
# 10968                      MOTORCYCLE-AUTOMOBILE COLLISION
# 25962                              MOTOR VEHICLE COLLISION
# 5924                                               no_text
# 29839                                              no_text
# 11693                                              no_text
# 25683                                              no_text
# 16858                                              no_text
# 17280                                              no_text
# 35314                                              no_text
# 32035                              MOTOR VEHICLE COLLISION
# 6970                                               no_text
# 25494                                              no_text
# 20915                                              no_text
# 33138                                              no_text
# 28817                                              no_text
# 16893                                              no_text
# 5537                                               no_text
# 31789                                              no_text
# 16343                                              no_text
# 20646                                              no_text
# 20641                                              no_text
# 9694                                               no_text
# 1895                                               no_text
# 28252                                              no_text
# 28419                                              no_text
# 25521                                              no_text
# 12323                                              no_text
# 16552                                     ETHANOL TOXICITY
# 25615                                              no_text
# 32397                                        STRANGULATION
# 31916                                              no_text
# 10958                                              no_text
# 29569                                              no_text
# 9410                                                  FALL
# 34689                                     UNWITNESSED FALL
# 17120                                              no_text
# 36630                                CHOKING ON FOOD BOLUS
# 30685                                              no_text
# 5750                                                  FALL
# 13011                                     FALL FROM HEIGHT
# 32013                 AUTOMOBILE COLLISION WITH PARKED CAR
# 3010                              PROBABLE OPIOID TOXICITY
# 30286                                              no_text
# 25423                                              no_text
# 30456                                              no_text
# 24477                                                 FALL
# 22139                                                 FALL
# 27813                                              no_text
# 15720                             ...AND COCAINE) TOXICITY
# 18744                                              no_text
# 25356                                              no_text
# 36771                                              no_text
# 3723                                                  FALL
# 1570     3,4-METHYLENEDIOXYMETHAMPHETAMINE [MDMA]) TOXI...
# 14659                                           HOUSE FIRE
# 5653                                               no_text
# 27309                                              no_text
# 10971                                              no_text
# 3397                                               no_text
# 29808                                              no_text
# 24919                                                 FALL
# 35163                                              no_text
# 9162                                               no_text
# 30253                                              no_text
# 8209     HYPERTENSIVE ARTERIOSCLEROTIC CARDIOVASCULAR D...
# 1335                                               no_text
# 31938                                              no_text
# 22704                                              no_text
# 27763                     BLUNT FORCE INJURIES OF THE HEAD
# 16446                                              no_text
# 8585                                               no_text
# 17682                                     FALL DOWN STAIRS
# 12373                                                 FALL
# 569                                         FALL ON STAIRS
# 10985                                              no_text
# 16684                                              no_text
# 2864                                               no_text
# 23610                                              no_text
# 21443                                              no_text
# 424                                                   FALL
# 25114                                              no_text
# 175                                          PROBABLE FALL
# 4404                                               no_text
# 28314                                              no_text
# 19508                                              no_text
# 15980                                              no_text
# 10194                                              no_text
# 16729                                              no_text
# 17422                   ...DESPROPIONYL FENTANYL (4-ANPP))
# 18143                                              no_text
# 36075                          ENVIRONMENTAL COLD EXPOSURE
# 8031                                               no_text
# 36400                                              no_text
# 11613                                PROMETHAZINE TOXICITY
# 23118                                                 FALL
# 12232                              MOTOR VEHICLE COLLISION
# 31654                                     UNWITNESSED FALL
# 13573                                              no_text
# 18301                                              no_text
# 30629                                              no_text
# 10162                                              no_text
# 8321                                               no_text
# 27277                                                 FALL
# 10964                              MOTOR VEHICLE COLLISION
# 1311                               MOTOR VEHICLE COLLISION
# 19601                  MOTOR VEHICLE STRIKING FIXED OBJECT
# 3522                                               no_text
# 24548                           UNWITNESSED FALL ON STAIRS
# 3974                                               no_text
# 27891                                                 FALL
# 22599                                              no_text
# 29613                                              no_text
# 12130                                     RESIDENTIAL FIRE
# 4777     MOTOR VEHICLE COLLISION WITH MOTOR VEHICLE SUB...
# 814                                MOTOR VEHICLE COLLISION
# 32054                                                 FALL
# 907                      MOTORCYCLE STRIKING MOTOR VEHICLE
# 2832                      AUTOMOBILE STRIKING FIXED OBJECT
# 17686                                REMOTE GUNSHOT WOUNDS
# 7419                                               no_text
# 34930                                              no_text
# 29718                                              no_text
# 23932                                              no_text
# 7194                               MOTOR VEHICLE COLLISION
# 9940                                               no_text
# 35479                                              no_text
# 22463                           PEDESTRIAN STRUCK BY TRAIN
# 641                                                no_text
# 899                                                no_text
# 17805                                              no_text
# 28551                                              no_text
# 29225                                              no_text
# 18637                                              no_text
# 12051                                              no_text
# 32374                                              no_text
# 8375                                               no_text
# 23181                                              no_text
# 5455                                      FALL DOWN STAIRS
# 30293                                              no_text
# 8644                      MOTOR VEHICLE CRASH DURING CHASE
# 19120                                              no_text
# 29814                                              no_text
# 9496                 PEDESTRIAN STRUCK BY MOTOR VEHICLE(S)
# 7493                                               no_text
# 22718                       AUTOMOBLILE STRIKING BICYCLIST
# 24853                                              no_text
# 36591                                              no_text
# 31796                                              no_text
# 3029     ...CLONAZEPAM, AND PROBABLE CLONAZOLAM, METONI...
# 24634                       MOTOR VEHICLE STRIKING BICYCLE
# 25818                                              no_text
# 11250                                              no_text
# 30740                                                 FALL
# 27422                                              no_text
# 3065                                               no_text
# 34100                        REMOTE ACETAMINOPHEN OVERDOSE
# 23219                                              no_text
# 3365                                               no_text
# 10455                                              no_text
# 19713                                              no_text
# 16427                                              no_text
# 33965                                     PINNED UNDER CAR
# 17979                        COCAINE, AND HEROIN) TOXICITY
# 18558    INHALATION OF THE PRODUCTS OF COMBUSTION AND P...
# 11362       . . .  MITRAGYNINE AND RECENT COCAINE TOXICITY
# 26397                                              no_text
# 20048                                              no_text
# 8552                                            HOUSE FIRE
# 2145                                               no_text
# 11270                                              no_text
# 28774          SPORT UTILITY VEHICLE STRIKING FIXED OBJECT
# 21683                                                 FALL
# 4046                                               no_text
# 14282                                                 FALL
# 33203           SPORTS UTILITY VEHICLE STRIKING PEDESTRIAN
# 13900                                              no_text
# 23279                                              no_text
# 21716                                              no_text
# 6334                                   MOTOR VEHICLE CRASH
# 22978                                              no_text
# 14152                                                 FALL
# 30300                                       REMOTE ASSAULT
# 12679                                              no_text
# 14417                    CARFENTANIL, AND HEROIN) TOXICITY
# 5424                                               no_text
# 870                                                no_text
# 4599                                               no_text
# 24270                                              no_text
# 11882                                           HOUSE FIRE
# 32051                                              no_text
# 24317                                              no_text
# 10163                                              no_text
# 15424                                              no_text
# 9740                                         PROBABLE FALL
# 19158                                              no_text
# 4236                                               no_text
# 8817                                               no_text
# 6895                                               no_text
# 4798                                MOTOR VEHICLE COLLSION
# 3652                                               no_text
# 7531                                               no_text
# 16622                                              no_text
# 33541                                                 FALL
# 6466                                               no_text
# 20122                                              no_text
# 30761                    MOTOR VEHICLE STRIKING PEDESTRIAN
# 25791                                              no_text
# 3508                                               no_text
# 34125                                MOTORCYCLE VERSUS CAR
# 8452                                               no_text
# 34309                                              no_text
# 24090                                              no_text
# 32656                              MOTOR VEHICLE COLLISION
# 24804                                              no_text
# 36505                                              no_text
# 22123                                              no_text
# 10447                                              no_text
# 14297                                              no_text
# 18392                                              no_text
# 2482                                               no_text
# 36153                                              no_text
# 16839                                              no_text
# 1043                             CHOKING ON FOREIGN OBJECT
# 6499                                               no_text
# 20958                                              no_text
# 26689                     DUE TO FALL FROM STANDING HEIGHT
# 7731                                                  FALL
# 22327                                              no_text
# 13326                                              no_text
# 10554                                              no_text
# 30319                                              no_text
# 21958                    MOTOR VEHICLE STRIKING PEDESTRIAN
# 35328                                              no_text
# 26974                                              no_text
# 3821                   MOTOR VEHICLE STRIKING FIXED OBJECT
# 8235                                               no_text
# 7390                                                   FAL
# 34717                                  MOTORCYCLE ACCIDENT
# 22699                                              no_text
# 10030                                              no_text
# 25175                                                 FALL
# 20098                                              no_text
# 13817                                              no_text
# 30805                                              HANGING
# 10758                                CHOKING ON FOOD BOLUS
# 27773                                              no_text
# 16345                                              no_text
# 9554                                               no_text
# 26268                                                 FALL
# 14285                                              no_text
# 13481                                              no_text
# 10880                                              no_text
# 35452                                              no_text
# 8353                               MOTOR VEHICLE COLLISION
# 30647                              CAR STRIKING MOTORCYCLE
# 13496                                              no_text
# 5915                                               no_text
# 4850                                               no_text
# 34063                                              no_text
# 6151                                                  FALL
# 15568                                              no_text
# 34703                                              HANGING
# 15118                              MOTOR VEHICLE COLLISION
# 233                                                ASSAULT
# 28704                                              no_text
# 20714                                              no_text
# 29793                                     UNWITNESSED FALL
# 9729             ...COCAINE, AND PROBABLE HEROIN) TOXICITY
# 10368                                     FALL FROM HEIGHT
# 17019                                              no_text
# 33901                                              no_text
# 36504                                              no_text
# 16170                                              no_text
# 34183                                              no_text
# 14397                                              no_text
# 11570                                              no_text
# 6965                                               no_text
# 35107                                              no_text
# 17428                                              no_text
# 11837                                                 FALL
# 18097                              MOTOR VEHICLE COLLISION
# 13231                                              no_text
# 21720                                  MOTOR VEHICLE CRASH
# 33300                                              no_text
# 18936                                              no_text
# 26909                                              no_text
# 30128                                  MOTOR VEHICLE CRASH
# 11905                          SPORT UTILITY VEHICLE CRASH
# 14486                                              no_text
# 8217                                               no_text
# 6954                    PEDESTRIAN STRUCK BY MOTOR VEHICLE
# 8340                                               no_text
# 5444                                               no_text
# 10603                                              no_text
# 5011                                               no_text
# 32937                                              no_text
# 12301                                                 FALL
# 58                                           PROBABLE FALL
# 14931                                              no_text
# 29210                                                 FALL
# 27264                                CHOKING ON FOOD BOLUS
# 11404                                              no_text
# 22709                                              HANGING
# 15048                                              ASSAULT
# 27254                                     JUMP FROM HEIGHT
# 32904                                              no_text
# 8623                                               no_text
# 13675                         ...PROBABLE HEROIN) TOXICITY
# 36013                                     FALL DOWN STAIRS
# 12409    . . .AND 4-ANPP (DESPROPIONYL FENTANYL)) TOXICITY
# 21284                                              no_text
# 24226                                              no_text
# 13994                                              no_text
# 16079                                              no_text
# 557                                                no_text
# 15603                                              no_text
# 26195                                              no_text
# 8657                                               no_text
# 21824                                              no_text
# 35176                                              no_text
# 7215                                               no_text
# 8723                                               no_text
# 5099                                               no_text
# Name: primary_cause_line_b, dtype: object

# %%
np.set_printoptions(threshold = False)

# %%
# this step turns out to be unnecessary, because we select the column we want to work with later

textdf = full_df[['manner_of_death', 'primary_cause', 'primary_cause_line_a', 
                  'primary_cause_line_b', 'primary_cause_line_c', 'secondary_cause']]
textdf.sample(5)

# %%
# make a stemmer and lemmatizer

wn = WordNetLemmatizer()
stemmer = PorterStemmer()

def lem_stem(text):
    return stemmer.stem(wn.lemmatize(text, pos='v'))

def preprocess(text):
    result = []
    for token in gensim.utils.simple_preprocess(text):
        if token not in gensim.parsing.preprocessing.STOPWORDS and len(token) > 3:
            result.append(lem_stem(token))
    return result

# %%
# test it's functioning as expected

doc_sample = textdf[textdf.index == 428].values[0][1]
print('original document: ')
words = []
for word in doc_sample.split(' '):
    words.append(word)
print(words)
print('\n\n tokenized and lemmatized document: ')
print(preprocess(doc_sample))

# %%
# process the 'primary_cause' column

processed_docs = textdf['primary_cause'].map(preprocess)
processed_docs[:10]

# %% [markdown]
# ## 🔥🔥🔥🔥🔥
# How do we customize the part-of-speech for 'wound' so that it's always a noun and doesn't sometimes get lemmatized to 'wind'; also check if 'left' is becoming 'leav'

# %%
# Create the Bag of Words (bow) for our data
# first, make a dictionary with words and number of times they occur in the corpus

dictionary = gensim.corpora.Dictionary(processed_docs)

# %%
# dictionary.token2id

# %%
# dictionary.cfs

# %%
# filter out tokens that appear in too few or too many docs

# these were the example settings; 
# need to check if they work for our data   🔥🔥🔥

dictionary.filter_extremes(no_below=15, no_above=0.5, keep_n=100000)

# %%
# make a dictionary for each document, 
# with how many words (by number of tuples) 
# and which word (based on its number in the dictionary)
# and how many times they appear

bow_corpus = [dictionary.doc2bow(doc) for doc in processed_docs]

# same example doc as above
bow_corpus[428]

# %%
# printed out nicely

bow_doc_428 = bow_corpus[428]
for i in range(len(bow_doc_428)):
    print("Word {} (\"{}\") appears {} time(s).".format(bow_doc_428[i][0], 
                                               dictionary[bow_doc_428[i][0]], 
bow_doc_428[i][1]))

# %%
# number in dictionary, word, times it appears on document
bow_doc_428[0][0], dictionary[bow_doc_428[0][0]], bow_doc_428[0][1]

# %%
# create tf-idf model and transform the corpus

tfidf = models.TfidfModel(bow_corpus)
corpus_tfidf = tfidf[bow_corpus]

# %%
# LDA run on bag of words

lda_model = gensim.models.LdaMulticore(bow_corpus, num_topics=10, 
                                       id2word=dictionary, passes=2, workers=2)


# check the words in each topic and their weights to see if they make sense

for idx, topic in lda_model.print_topics(-1):
    print('Topic: {} \nWords: {}'.format(idx, topic))

# %%
# check where sample doc would be classified in bag of words model
print(processed_docs[428])

for index, score in sorted(lda_model[bow_corpus[428]], key=lambda tup: -1*tup[1]):
    print("\nScore: {}\t \nTopic: {}".format(score, lda_model.print_topic(index, 10)))

# %%
# LDA run on tfidf

lda_model_tfidf = gensim.models.LdaMulticore(corpus_tfidf, num_topics=10, 
                                             id2word=dictionary, passes=2, workers=4)

# check the words in each topic and their weights to see if they make sense

for idx, topic in lda_model_tfidf.print_topics(-1):
    print('Topic: {} Word: {}'.format(idx, topic))

# %%
# check where sample doc would be classified in tfidf model
print(processed_docs[428])

for index, score in sorted(lda_model_tfidf[bow_corpus[428]], key=lambda tup: -1*tup[1]):
    print("\nScore: {}\t \nTopic: {}".format(score, lda_model_tfidf.print_topic(index, 10)))

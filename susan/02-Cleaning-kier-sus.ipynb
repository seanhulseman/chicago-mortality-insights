# %% [markdown]
# authors: Kiersten Johns, Susan Hopper

# %% [markdown]
# # Imports:

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
pd.set_option('display.max_columns', None)

# %%
partial_clean = pd.read_csv('../kiersten/data/dataframe.csv')
partial_clean.head(2)
# Out:
#    Unnamed: 0        date_of_incident           date_of_death   age  gender  \
# 0          20  10/24/2023 12:43:00 AM  10/25/2023 12:11:00 AM  22.0  Female
# 1          22  10/24/2023 10:30:00 PM  10/24/2023 09:51:00 PM  35.0    Male
#
#     race  latino manner_of_death  \
# 0  Black   False        ACCIDENT
# 1  Black   False        HOMICIDE
#
#                                        primary_cause  \
# 0  MULTIPLE BLUNT FORCE INJURIES. MOTOR VEHICLE C...
# 1                            MULTIPLE GUNSHOT WOUNDS
#
#             primary_cause_line_a     primary_cause_line_b  \
# 0  MULTIPLE BLUNT FORCE INJURIES  MOTOR VEHICLE COLLISION
# 1        MULTIPLE GUNSHOT WOUNDS                      NaN
#
#   primary_cause_line_c secondary_cause  gun_related  opioid_related  \
# 0                  NaN             NaN        False           False
# 1                  NaN             NaN         True           False
#
#    cold_related  heat_related  commissioner_district incident_city  \
# 0         False         False                    1.0       CHICAGO
# 1         False         False                    4.0       CHICAGO
#
#    incident_zip_code  longitude   latitude residence_city  residence_zip  \
# 0            60644.0 -87.754890  41.872093   Indianapolis        46224.0
# 1            60649.0 -87.558292  41.759939        Chicago        60633.0
#
#   chicago_community_area  covid_related
# 0                 AUSTIN          False
# 1            SOUTH SHORE          False

# %%
# drop the extra index column

partial_clean.drop(columns=['Unnamed: 0'], inplace=True)

# %%
# drop rows where gender is unknown

partial_clean.dropna(subset=['gender'], inplace=True)
partial_clean.drop(partial_clean[partial_clean['gender'] == 'Unknown'].index, inplace=True)

# %%
# partial_clean['incident_zip_code'].unique()

# %%
partial_clean[partial_clean['residence_zip']==0][:3]
# Out:
#             date_of_incident           date_of_death   age  gender   race  \
# 3074  01/25/2023 07:26:00 PM  01/27/2023 06:48:00 PM  54.0  Female  Black
# 3300  01/10/2023 04:30:00 PM  01/10/2023 04:44:00 PM  40.0    Male  Black
# 3499  12/29/2022 10:08:00 AM  12/29/2022 10:28:00 AM  45.0    Male  White
#
#       latino manner_of_death  \
# 3074   False        ACCIDENT
# 3300   False        ACCIDENT
# 3499   False        ACCIDENT
#
#                                           primary_cause  \
# 3074  COMPLICATIONS OF MULTIPLE INJURIES. PEDESTRIAN...
# 3300  COMBINED DRUG (FENTANYL, DESPROPIONYL FENTANYL...
# 3499  COMBINED DRUG (COCAINE, FENTANYL, DESPROPIONYL...
#
#                                    primary_cause_line_a  \
# 3074                 COMPLICATIONS OF MULTIPLE INJURIES
# 3300  COMBINED DRUG (FENTANYL, DESPROPIONYL FENTANYL...
# 3499  COMBINED DRUG (COCAINE, FENTANYL, DESPROPIONYL...
#
#                     primary_cause_line_b primary_cause_line_c  \
# 3074  PEDESTRIAN STRUCK BY MOTOR VEHICLE                  NaN
# 3300                                 NaN                  NaN
# 3499                                 NaN                  NaN
#
#              secondary_cause  gun_related  opioid_related  cold_related  \
# 3074                     NaN        False           False         False
# 3300                     NaN        False            True         False
# 3499  PROBABLE COLD EXPOSURE        False            True         False
#
#       heat_related  commissioner_district incident_city  incident_zip_code  \
# 3074         False                    1.0       CHICAGO            60651.0
# 3300         False                    2.0       CHICAGO            60602.0
# 3499         False                    5.0     RIVERDALE            60827.0
#
#       longitude   latitude residence_city  residence_zip  \
# 3074 -87.726197  41.895388            NaN            0.0
# 3300 -87.627971  41.882697            NaN            0.0
# 3499 -87.636228  41.646622            NaN            0.0
#
#      chicago_community_area  covid_related
# 3074          HUMBOLDT PARK          False
# 3300                   LOOP          False
# 3499                    NaN          False

# %%
# replace 0 values with NaNs in zipcode fields, so they get replaced with 'no_text' later

partial_clean['incident_zip_code'].replace(0, np.NaN, inplace=True)
partial_clean['residence_zip'].replace(0, np.NaN, inplace=True)

# %%
# make zip codes into 5-char strings and preseve the nulls

inc_zip_nulls = partial_clean['incident_zip_code'].isna()
partial_clean['incident_zip_code'] = partial_clean['incident_zip_code'].astype(str).mask(inc_zip_nulls, np.NaN).str[:5]

res_zip_nulls = partial_clean['residence_zip'].isna()
partial_clean['residence_zip'] = partial_clean['residence_zip'].astype(str).mask(res_zip_nulls, np.NaN).str[:5]

# %%
# fill nulls with agreed-upon values
# I also added 'no_text' for secondary_cause nulls

partial_clean['race'].fillna('Unknown', inplace=True)
partial_clean['primary_cause_line_b'].fillna('no_text', inplace=True)
partial_clean['primary_cause_line_c'].fillna('no_text', inplace=True)
partial_clean['secondary_cause'].fillna('no_text', inplace=True)
partial_clean['commissioner_district'].fillna('no_text', inplace=True)
partial_clean['incident_city'].fillna('no_text', inplace=True)
partial_clean['incident_zip_code'].fillna('no_text', inplace=True)
partial_clean['residence_city'].fillna('no_text', inplace=True)
partial_clean['residence_zip'].fillna('no_text', inplace=True)
partial_clean['chicago_community_area'].fillna('no_text', inplace=True)

# %%
# fill in nulls for death date and age (the special cases): 

partial_clean[partial_clean['date_of_death'].isna()]
# Out:
#              date_of_incident date_of_death   age  gender   race  latino  \
# 31775  03/26/2016 09:07:00 AM           NaN  70.0  Female  White   False
#
#       manner_of_death                                      primary_cause  \
# 31775        ACCIDENT  COMPLICATIONS OF SUBDURAL HEMATOMA . DUE TO FA...
#
#                      primary_cause_line_a    primary_cause_line_b  \
# 31775  COMPLICATIONS OF SUBDURAL HEMATOMA  DUE TO FALL DOWNSTAIRS
#
#       primary_cause_line_c secondary_cause  gun_related  opioid_related  \
# 31775              no_text         no_text        False           False
#
#        cold_related  heat_related commissioner_district   incident_city  \
# 31775         False         False                  17.0  LA GRANGE PARK
#
#       incident_zip_code  longitude   latitude  residence_city residence_zip  \
# 31775             60526 -87.867411  41.836726  La Grange Park         60526
#
#       chicago_community_area  covid_related
# 31775                no_text          False

# %%
partial_clean['date_of_death'].fillna('03/26/2016 09:07:00 AM', inplace=True)

# %%
partial_clean['age'].fillna(99999999, inplace=True)

# %%
def age_buckets(x):
    if int(x) < 5:
        return 'Under 5'
    elif int(x) < 15:
        return '5-14'
    elif int(x) < 25:
        return '15-24'
    elif int(x) < 65:
        return '25-64'
    elif int(x) < 99999999:
        return '65+'
    else:
        return 'Unknown'

# %%
partial_clean['age_range'] = partial_clean['age'].apply(age_buckets)

# %%
# make the binary categories 1s and 0s

partial_clean['latino'] = partial_clean.latino.map({False : 0, True : 1})
partial_clean['cold_related'] = partial_clean.cold_related.map({False : 0, True : 1})
partial_clean['heat_related'] = partial_clean.heat_related.map({False : 0, True : 1})
partial_clean['gun_related'] = partial_clean.gun_related.map({False : 0, True : 1})
partial_clean['opioid_related'] = partial_clean.opioid_related.map({False : 0, True : 1})
partial_clean['covid_related'] = partial_clean.covid_related.map({False : 0, True : 1})
partial_clean['gender'] = partial_clean.gender.map({'Male' : 0, 'Female' : 1})

# %%
# split the datetime columns into separate date and time columns and add day of week

partial_clean['date_of_death'] = pd.to_datetime(partial_clean['date_of_death'])
partial_clean['death_date'] = pd.to_datetime(partial_clean['date_of_death'].dt.date)
partial_clean['death_time'] = partial_clean['date_of_death'].dt.time
partial_clean['death_day'] = partial_clean['death_date'].dt.day_name()


partial_clean['date_of_incident'] = pd.to_datetime(partial_clean['date_of_incident'], errors='coerce')
partial_clean['inc_date'] = pd.to_datetime(partial_clean['date_of_incident'].dt.date)
partial_clean['inc_time'] = partial_clean['date_of_incident'].dt.time
partial_clean['inc_day'] = partial_clean['inc_date'].dt.day_name()

# %%
partial_clean.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 37151 entries, 0 to 37157
# Data columns (total 32 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   date_of_incident        36688 non-null  datetime64[ns]
#  1   date_of_death           37151 non-null  datetime64[ns]
#  2   age                     37151 non-null  float64
#  3   gender                  37151 non-null  int64
#  4   race                    37151 non-null  object
#  5   latino                  37151 non-null  int64
#  6   manner_of_death         37151 non-null  object
#  7   primary_cause           37151 non-null  object
#  8   primary_cause_line_a    37151 non-null  object
#  9   primary_cause_line_b    37151 non-null  object
#  10  primary_cause_line_c    37151 non-null  object
#  11  secondary_cause         37151 non-null  object
#  12  gun_related             37151 non-null  int64
#  13  opioid_related          37151 non-null  int64
#  14  cold_related            37151 non-null  int64
#  15  heat_related            37151 non-null  int64
#  16  commissioner_district   37151 non-null  object
#  17  incident_city           37151 non-null  object
#  18  incident_zip_code       37151 non-null  object
#  19  longitude               32076 non-null  float64
#  20  latitude                32076 non-null  float64
#  21  residence_city          37151 non-null  object
#  22  residence_zip           37151 non-null  object
#  23  chicago_community_area  37151 non-null  object
#  24  covid_related           37151 non-null  int64
#  25  age_range               37151 non-null  object
#  26  death_date              37151 non-null  datetime64[ns]
#  27  death_time              37151 non-null  object
#  28  death_day               37151 non-null  object
#  29  inc_date                36688 non-null  datetime64[ns]
#  30  inc_time                36688 non-null  object
#  31  inc_day                 36688 non-null  object
# dtypes: datetime64[ns](4), float64(3), int64(7), object(18)
# memory usage: 9.4+ MB

# %%
partial_clean.sample(3)
# Out:
#          date_of_incident       date_of_death   age  gender   race  latino  \
# 6319  2022-06-15 11:59:00 2022-06-15 12:01:00  23.0       0  Black       0
# 31100 2016-08-01 00:47:00 2016-08-04 13:55:00  52.0       1  Black       0
# 31452 2016-06-28 23:29:00 2016-06-29 00:20:00  29.0       1  White       1
#
#       manner_of_death                                      primary_cause  \
# 6319         ACCIDENT  ALPRAZOLAM, PROMETHAZINE, DIPHENHYDRAMINE, COD...
# 31100        ACCIDENT            COMPLICATIONS OF PHENCYCLIDINE TOXICITY
# 31452        ACCIDENT                                    OPIATE TOXICITY
#
#                                     primary_cause_line_a primary_cause_line_b  \
# 6319   ALPRAZOLAM, PROMETHAZINE, DIPHENHYDRAMINE, COD...              no_text
# 31100            COMPLICATIONS OF PHENCYCLIDINE TOXICITY              no_text
# 31452                                    OPIATE TOXICITY              no_text
#
#       primary_cause_line_c                                    secondary_cause  \
# 6319               no_text                                            no_text
# 31100              no_text  HYPERTENSIVE CARDIOVASCULAR DISEASE, MORBID OB...
# 31452              no_text                                            no_text
#
#        gun_related  opioid_related  cold_related  heat_related  \
# 6319             0               1             0             0
# 31100            0               0             0             0
# 31452            0               1             0             0
#
#       commissioner_district incident_city incident_zip_code  longitude  \
# 6319                    5.0     RIVERDALE             60827 -87.629242
# 31100                   2.0       CHICAGO             60621 -87.642901
# 31452                   1.0   WESTCHESTER             60154 -87.868913
#
#         latitude residence_city residence_zip chicago_community_area  \
# 6319   41.640593      Riverdale         60827                no_text
# 31100  41.773085        Chicago         60637              ENGLEWOOD
# 31452  41.856751        Chicago         60634                no_text
#
#        covid_related age_range death_date death_time  death_day   inc_date  \
# 6319               0     15-24 2022-06-15   12:01:00  Wednesday 2022-06-15
# 31100              0     25-64 2016-08-04   13:55:00   Thursday 2016-08-01
# 31452              0     25-64 2016-06-29   00:20:00  Wednesday 2016-06-28
#
#        inc_time    inc_day
# 6319   11:59:00  Wednesday
# 31100  00:47:00     Monday
# 31452  23:29:00    Tuesday

# %%
partial_clean.to_csv('../susan/data/partial_clean_data_kjsh.csv', index=False)

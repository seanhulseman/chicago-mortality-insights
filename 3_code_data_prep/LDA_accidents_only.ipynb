# %% [markdown]
# Author: Susan Hopper

# %% [markdown]
# ## LDA Topic Modeling on full primary cause, for accidental deaths only
# Credit where credit is due! Based on the work of Selva Prabhakaran, https://www.machinelearningplus.com/nlp/topic-modeling-gensim-python/

# %%
# in CLI:
# pip install pyLDAvis

# %%
# Imports
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

from nltk.corpus import stopwords
from nltk.stem import PorterStemmer

import gensim
import gensim.corpora as corpora
from gensim.utils import simple_preprocess
from gensim.models import CoherenceModel

from sklearn.model_selection import GridSearchCV

import pyLDAvis
import pyLDAvis.gensim

from pprint import pprint

import pickle

# %%
# Read in the cleaned data
df = pd.read_csv('../1_data/cleaned_data_31OCT.csv')

# %%
df.head(2)

# %%
df['manner_of_death'].value_counts()

# %%
# Make a dataframe of just 'ACCIDENT' manner of death
df_acc = df[df['manner_of_death']=='ACCIDENT']

# %%
# Reset the index
# df_acc.reset_index(drop=True, inplace=True)
# df_acc.head(1)

# %%
df_acc.columns

# %%
# Find accidental deaths that aren't already classified by the ME's office

unclass_acc = df_acc[(df_acc['gun_related']==0) & (df_acc['opioid_related']==0) & (df_acc['cold_related']==0) & (df_acc['heat_related']==0)]

# %%
# Reset the index
# unclass_acc.reset_index(drop=True, inplace=True)
# unclass_acc.head(1)

# %%
unclass_acc.index

# %%
# Define a stemming function

stop_words = stopwords.words('english')
ps = PorterStemmer()

def preprocess(text):
    result = []
    for token in gensim.utils.simple_preprocess(text):
        if token not in stop_words and len(token) > 2:
            result.append(ps.stem(token))
    return result

# %%
# Test it's functioning as expected

doc_sample = unclass_acc[unclass_acc.index == 1001].values[0][8]

print('original document: ')
words = []
for word in doc_sample.split(' '):
    words.append(word)
print(words)

print('\nstemmed document: ')
print(preprocess(doc_sample))

# %%
# Process the 'primary_cause' column

data_words = unclass_acc['primary_cause'].map(preprocess).tolist()

# %%
# Build bigram model and function, and make bigrams

bigram = gensim.models.Phrases(data_words, min_count=1, threshold=1) 

bigram_mod = gensim.models.phrases.Phraser(bigram)

def make_bigrams(texts):
    return [bigram_mod[doc] for doc in texts]

data_words_bigrams = make_bigrams(data_words)

data_words[:5]
# Out:
# [['multipl', 'blunt', 'forc', 'injuri', 'motor', 'vehicl', 'collis'],
#  ['multipl', 'injuri', 'bicyclist', 'struck', 'motor', 'vehicl'],
#  ['multipl', 'injuri', 'scooter', 'motor', 'vehicl', 'collis'],
#  ['complic', 'multipl', 'injuri', 'fall', 'ladder'],
#  ['multipl', 'injuri', 'motor', 'vehicl', 'strike', 'pedestrian']]

# %%
# Create dictionary for the model
id2word = corpora.Dictionary(data_words_bigrams)

# Create corpus for the model
texts = data_words_bigrams

# Find term document frequency
corpus = [id2word.doc2bow(text) for text in texts]

# %%
# Check the processing with human-readable format of corpus (term, frequency in doc)
[[(id2word[id], freq) for id, freq in cp] for cp in corpus[25:30]]

# %%
# Build LDA model on full accident dataset

lda_model_accid = gensim.models.ldamodel.LdaModel(corpus=corpus,
                                               id2word=id2word,
                                               num_topics=3,
                                               random_state=42,
                                               update_every=1,
                                               chunksize=3000,
                                               passes=20,
                                               alpha='auto',
                                               per_word_topics=True)

# %%
# Visualize the topics
pyLDAvis.enable_notebook()
vis = pyLDAvis.gensim.prepare(lda_model_accid, corpus, id2word)

vis

# %%
# Compute perplexity, a measure of how good the model is. Lower is better.
print('\nPerplexity: ', lda_model_accid.log_perplexity(corpus))  

# Compute coherence score, a measure of how well the elements of the topic support each other. 
# Cohesion relates to human comprehension better than perplexity
coherence_model_lda = CoherenceModel(model=lda_model_accid, texts=data_words_bigrams, dictionary=id2word, coherence='c_v')
coherence_lda = coherence_model_lda.get_coherence()
print('\nCoherence Score: ', coherence_lda)

# %%
# Thanks, Tim!
lda_model_accid.get_document_topics(corpus[0])

# %%
# Print keywords in each topic
pprint(lda_model_accid.print_topics())
doc_lda = lda_model_accid[corpus]

# %%
# Define a function to find the most relevant topic
def best_topic(corpus):
    best_topic_list = []
    for i in range(0, len(corpus)):
        best_topic = (sorted(lda_model_accid.get_document_topics(corpus[i]), key=lambda x: x[1], reverse=True))[0][0]
        best_topic_list.append(best_topic)
    return best_topic_list

best_topic_column = best_topic(corpus)

# %%
# Define a function to get the percentage for the most relevant topic
def topic_perc(corpus):
    topic_perc_list = []
    for i in range(0, len(corpus)):
        perc_topic = (sorted(lda_model_accid.get_document_topics(corpus[i]), key=lambda x: x[1], reverse=True))[0][1]
        topic_perc_list.append(perc_topic)
    return topic_perc_list

topic_perc_column = topic_perc(corpus)

# %%
# Add topic columns to the smaller df
unclass_acc['long_topic'] = lda_model_accid.get_document_topics(corpus)
unclass_acc['best_topic_num'] = best_topic_column
unclass_acc['best_topic_name'] = unclass_acc['best_topic_num'].map(
                                                {0:'vehicle_collision', 
                                                 1:'fall', 
                                                 2:'choking_misc'})
unclass_acc['best_topic_perc'] = topic_perc_column
# Out:
# /var/folders/hd/_s2x4yxn2cvgc7_fjy3dz4cr0000gn/T/ipykernel_6032/2123644719.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   unclass_acc['long_topic'] = lda_model_accid.get_document_topics(corpus)
# /var/folders/hd/_s2x4yxn2cvgc7_fjy3dz4cr0000gn/T/ipykernel_6032/2123644719.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   unclass_acc['best_topic_num'] = best_topic_column
# /var/folders/hd/_s2x4yxn2cvgc7_fjy3dz4cr0000gn/T/ipykernel_6032/2123644719.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   unclass_acc['best_topic_name'] = unclass_acc['best_topic_num'].map(
# /var/folders/hd/_s2x4yxn2cvgc7_fjy3dz4cr0000gn/T/ipykernel_6032/2123644719.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   unclass_acc['best_topic_perc'] = topic_perc_column

# %%
# Check how it looks
unclass_acc[['primary_cause_line_a', 'primary_cause_line_b', 'long_topic', 'best_topic_num', 'best_topic_name','best_topic_perc', ]].sample(10)

# %%
# Merge the topic columns to the larger accident df

df_acc_topics = pd.merge(left = df_acc, right = unclass_acc, how='left')

# %%
df_acc_topics.head(10)
# Out:
#       date_of_incident        date_of_death   age  gender   race  latino  \
# 0  2023-10-24 00:43:00  2023-10-25 00:11:00  22.0       1  Black       0
# 1  2023-10-23 20:52:00  2023-10-23 20:32:00  59.0       0  White       0
# 2  2023-10-23 16:41:00  2023-10-23 15:29:00  79.0       1  White       0
# 3                  NaN  2023-10-22 11:28:00  58.0       0  White       0
# 4  2023-10-19 19:48:00  2023-10-21 19:37:00  72.0       1  White       1
# 5  2023-10-21 08:04:00  2023-10-21 06:45:00  68.0       0  Black       0
# 6  2023-09-28 15:08:00  2023-10-09 13:48:00  63.0       0  Black       0
# 7  2023-10-12 03:39:00  2023-10-21 01:31:00  88.0       1  White       0
# 8  2023-10-20 21:00:00  2023-10-20 20:03:00  36.0       0  White       1
# 9  2023-09-27 13:28:00  2023-10-19 10:24:00  52.0       0  White       1
#
#   manner_of_death                                      primary_cause  \
# 0        ACCIDENT  MULTIPLE BLUNT FORCE INJURIES. MOTOR VEHICLE C...
# 1        ACCIDENT  MULTIPLE INJURIES. BICYCLIST STRUCK BY MOTOR V...
# 2        ACCIDENT  MULTIPLE INJURIES. SCOOTER AND MOTOR VEHICLE C...
# 3        ACCIDENT  COMPLICATIONS OF MULTIPLE INJURIES. FALL OFF L...
# 4        ACCIDENT  MULTIPLE INJURIES. MOTOR VEHICLE STRIKING PEDE...
# 5        ACCIDENT          COMPLICATIONS OF REMOTE DRUG INTOXICATION
# 6        ACCIDENT  COMPLICATIONS OF ETHANOL AND METHADONE INTOXIC...
# 7        ACCIDENT  COMPLICATIONS OF BLUNT FORCE INJURIES OF LEFT ...
# 8        ACCIDENT  MULTIPLE INJURIES. MOTORCYCLE STRIKING MOTOR V...
# 9        ACCIDENT  COMPLICATIONS FOLLOWING THERMAL AND INHALATION...
#
#                                 primary_cause_line_a  \
# 0                      MULTIPLE BLUNT FORCE INJURIES
# 1                                  MULTIPLE INJURIES
# 2                                  MULTIPLE INJURIES
# 3                 COMPLICATIONS OF MULTIPLE INJURIES
# 4                                  MULTIPLE INJURIES
# 5          COMPLICATIONS OF REMOTE DRUG INTOXICATION
# 6  COMPLICATIONS OF ETHANOL AND METHADONE INTOXIC...
# 7  COMPLICATIONS OF BLUNT FORCE INJURIES OF LEFT HIP
# 8                                  MULTIPLE INJURIES
# 9  COMPLICATIONS FOLLOWING THERMAL AND INHALATION...
#
#                    primary_cause_line_b  ...  death_date death_time  \
# 0               MOTOR VEHICLE COLLISION  ...  2023-10-25   00:11:00
# 1  BICYCLIST STRUCK BY MOTOR VEHICLE(S)  ...  2023-10-23   20:32:00
# 2   SCOOTER AND MOTOR VEHICLE COLLISION  ...  2023-10-23   15:29:00
# 3                       FALL OFF LADDER  ...  2023-10-22   11:28:00
# 4     MOTOR VEHICLE STRIKING PEDESTRIAN  ...  2023-10-21   19:37:00
# 5                               no_text  ...  2023-10-21   06:45:00
# 6                               no_text  ...  2023-10-09   13:48:00
# 7                                  FALL  ...  2023-10-21   01:31:00
# 8     MOTORCYCLE STRIKING MOTOR VEHICLE  ...  2023-10-20   20:03:00
# 9             RECREATIONAL VEHICLE FIRE  ...  2023-10-19   10:24:00
#
#    death_day    inc_date  inc_time    inc_day  \
# 0  Wednesday  2023-10-24  00:43:00    Tuesday
# 1     Monday  2023-10-23  20:52:00     Monday
# 2     Monday  2023-10-23  16:41:00     Monday
# 3     Sunday         NaN       NaN        NaN
# 4   Saturday  2023-10-19  19:48:00   Thursday
# 5   Saturday  2023-10-21  08:04:00   Saturday
# 6     Monday  2023-09-28  15:08:00   Thursday
# 7   Saturday  2023-10-12  03:39:00   Thursday
# 8     Friday  2023-10-20  21:00:00     Friday
# 9   Thursday  2023-09-27  13:28:00  Wednesday
#
#                                           long_topic best_topic_num  \
# 0  [(0, 0.91106987), (1, 0.06506033), (2, 0.02386...            0.0
# 1  [(0, 0.8928988), (1, 0.07840207), (2, 0.028699...            0.0
# 2  [(0, 0.9110208), (1, 0.06510562), (2, 0.023873...            0.0
# 3  [(0, 0.69110024), (1, 0.28020066), (2, 0.02869...            0.0
# 4  [(0, 0.8929103), (1, 0.078391515), (2, 0.02869...            0.0
# 5  [(0, 0.28813913), (1, 0.6831598), (2, 0.028701...            1.0
# 6                                                NaN            NaN
# 7  [(0, 0.3576391), (1, 0.61849093), (2, 0.023869...            1.0
# 8  [(0, 0.7430392), (1, 0.065204225), (2, 0.19175...            0.0
# 9  [(0, 0.7729235), (1, 0.20663129), (2, 0.020445...            0.0
#
#      best_topic_name  best_topic_perc
# 0  vehicle_collision         0.911070
# 1  vehicle_collision         0.892898
# 2  vehicle_collision         0.911021
# 3  vehicle_collision         0.691088
# 4  vehicle_collision         0.892911
# 5               fall         0.683160
# 6                NaN              NaN
# 7               fall         0.618486
# 8  vehicle_collision         0.743039
# 9  vehicle_collision         0.772923
#
# [10 rows x 36 columns]

# %%
# Save the df as a csv

df_acc_topics.to_csv('../1_data/accidental_death_topics.csv', index=False)
